# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '0.23.3'

# %%
base_df = pd.read_csv('./data/full_data_set.csv')
base_df.head()
# Out:
#            Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0    Arian Foster  HOU     @IND     away  42.0    0    0    0   0    0
# 1      Matt Forte  CHI     @DET     away  38.0    0    0    0   0    0
# 2  Peyton Manning  IND      HOU     home  35.0   57   40  433   3    0
# 3    Chad Johnson  CIN       NE     home  33.0    0    0    0   0    0
# 4   Austin Collie  IND      HOU     home  32.0    0    0    0   0    0
#
#      ...     Rush 2Pt  Rec  Rec Yds  Rec TD  Rec 2Pt  FL  Misc TD  Week  Year  \
# 0    ...            0    1        7       0        0   0        0     1  2010
# 1    ...            0    7      151       2        0   1        0     1  2010
# 2    ...            0    0        0       0        0   0        0     1  2010
# 3    ...            0   12      159       1        0   0        0     1  2010
# 4    ...            0   11      163       1        0   1        0     1  2010
#
#    Position
# 0        RB
# 1        RB
# 2        QB
# 3        WR
# 4        WR
#
# [5 rows x 24 columns]

# %%
base_df.shape
# Out:
# (12800, 24)

# %% [markdown]
# ### remove the @ symbol from the opponent team

# %%
base_df['Opponent'] = base_df['Opponent'].str.replace('@', '')
base_df.head()
# Out:
#            Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0    Arian Foster  HOU      IND     away  42.0    0    0    0   0    0
# 1      Matt Forte  CHI      DET     away  38.0    0    0    0   0    0
# 2  Peyton Manning  IND      HOU     home  35.0   57   40  433   3    0
# 3    Chad Johnson  CIN       NE     home  33.0    0    0    0   0    0
# 4   Austin Collie  IND      HOU     home  32.0    0    0    0   0    0
#
#      ...     Rush 2Pt  Rec  Rec Yds  Rec TD  Rec 2Pt  FL  Misc TD  Week  Year  \
# 0    ...            0    1        7       0        0   0        0     1  2010
# 1    ...            0    7      151       2        0   1        0     1  2010
# 2    ...            0    0        0       0        0   0        0     1  2010
# 3    ...            0   12      159       1        0   0        0     1  2010
# 4    ...            0   11      163       1        0   1        0     1  2010
#
#    Position
# 0        RB
# 1        RB
# 2        QB
# 3        WR
# 4        WR
#
# [5 rows x 24 columns]

# %% [markdown]
# ### One-hot encode the position and label encode the teams and players

# %%
# save the position
base_df['pos_id'] = base_df['Position']
# one-hot encode the position
df = pd.get_dummies(base_df, columns=['Position'])

# %%
ids = np.array([k for k in base_df['Opponent'].unique()])
team_names = ids.copy()
df['opp_team'] = df['Opponent'].apply(lambda x: np.where(x == ids)[0][0])
df['team'] = df['Team'].apply(lambda x: np.where(x == ids)[0][0])
df.head(15)
# Out:
#              Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0      Arian Foster  HOU      IND     away  42.0    0    0    0   0    0
# 1        Matt Forte  CHI      DET     away  38.0    0    0    0   0    0
# 2    Peyton Manning  IND      HOU     home  35.0   57   40  433   3    0
# 3      Chad Johnson  CIN       NE     home  33.0    0    0    0   0    0
# 4     Austin Collie  IND      HOU     home  32.0    0    0    0   0    0
# 5     Chris Johnson  TEN      OAK     away  30.0    0    0    0   0    0
# 6      Miles Austin  DAL      WAS     home  30.0    0    0    0   0    0
# 7      Hakeem Nicks  NYG      CAR     away  29.0    0    0    0   0    0
# 8         Tom Brady   NE      CIN     away  28.0   35   25  258   3    0
# 9        Wes Welker   NE      CIN     away  26.0    0    0    0   0    0
# 10  Darren McFadden  OAK      TEN     home  26.0    0    0    0   0    0
# 11    David Garrard  JAX      DEN     away  25.0   21   16  170   3    0
# 12       Jay Cutler  CHI      DET     away  25.0   35   23  372   2    1
# 13     Dallas Clark  IND      HOU     home  25.0    0    0    0   0    0
# 14      Roddy White  ATL      PIT     home  24.0    0    0    0   0    0
#
#     ...   Misc TD  Week  Year  pos_id  Position_QB  Position_RB  Position_TE  \
# 0   ...         0     1  2010      RB            0            1            0
# 1   ...         0     1  2010      RB            0            1            0
# 2   ...         0     1  2010      QB            1            0            0
# 3   ...         0     1  2010      WR            0            0            0
# 4   ...         0     1  2010      WR            0            0            0
# 5   ...         0     1  2010      RB            0            1            0
# 6   ...         0     1  2010      WR            0            0            0
# 7   ...         0     1  2010      WR            0            0            0
# 8   ...         0     1  2010      QB            1            0            0
# 9   ...         0     1  2010      WR            0            0            0
# 10  ...         0     1  2010      RB            0            1            0
# 11  ...         0     1  2010      QB            1            0            0
# 12  ...         0     1  2010      QB            1            0            0
# 13  ...         0     1  2010      TE            0            0            1
# 14  ...         0     1  2010      WR            0            0            0
#
#     Position_WR  opp_team  team
# 0             0         0     2
# 1             0         1    18
# 2             0         2     0
# 3             1         3     7
# 4             1         2     0
# 5             0         4     8
# 6             1         5    29
# 7             1         6    20
# 8             0         7     3
# 9             1         7     3
# 10            0         8     4
# 11            0         9    24
# 12            0         1    18
# 13            0         2     0
# 14            1        10    14
#
# [15 rows x 30 columns]

# %%
# Alternatively, you can use:
# df['opp_team'] = df['Opponent'].astype('category').cat.codes

# %%
player_names = df['Player'].unique()
df['player_id'] = df['Player'].apply(lambda x: np.where(x == player_names)[0][0])
df.head()
# Out:
#            Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0    Arian Foster  HOU      IND     away  42.0    0    0    0   0    0
# 1      Matt Forte  CHI      DET     away  38.0    0    0    0   0    0
# 2  Peyton Manning  IND      HOU     home  35.0   57   40  433   3    0
# 3    Chad Johnson  CIN       NE     home  33.0    0    0    0   0    0
# 4   Austin Collie  IND      HOU     home  32.0    0    0    0   0    0
#
#      ...      Week  Year  pos_id  Position_QB  Position_RB  Position_TE  \
# 0    ...         1  2010      RB            0            1            0
# 1    ...         1  2010      RB            0            1            0
# 2    ...         1  2010      QB            1            0            0
# 3    ...         1  2010      WR            0            0            0
# 4    ...         1  2010      WR            0            0            0
#
#    Position_WR  opp_team  team  player_id
# 0            0         0     2          0
# 1            0         1    18          1
# 2            0         2     0          2
# 3            1         3     7          3
# 4            1         2     0          4
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Compute the 5-game running average for each player

# %%
# Currently, the average includes the current week, I would ideally like the average to only include the previous four weeks
# Need to figure out how to do that

tmp = df.groupby('Player').apply(lambda x: x['Pts'].rolling(5).mean())
tojoin = tmp.reset_index().set_index('level_1')

# %%
tojoin.columns = ['player', '5_game_avg']
tojoin.head()
# Out:
#             player  5_game_avg
# level_1
# 11544     AJ Derby         NaN
# 11886     AJ Derby         NaN
# 11980     AJ Derby         NaN
# 2372     AJ Feeley         NaN
# 1709      AJ Green         NaN

# %%
new_df = pd.concat([df, tojoin], axis=1)
new_df.dropna()
# Out:
#                     Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  \
# 400           Hakeem Nicks  NYG      HOU     home  37.0    0    0    0   0
# 407          Philip Rivers   SD      OAK     home  28.0   42   27  431   2
# 415             Kyle Orton  DEN      BAL     home  24.0   38   23  314   2
# 422            Roddy White  ATL      CLE     home  21.0    0    0    0   0
# 429          Antonio Gates   SD      OAK     home  20.0    0    0    0   0
# 435          Aaron Rodgers   GB      WAS     home  18.0   46   27  293   1
# 443             Drew Brees   NO      ARI     home  17.0   39   24  279   2
# 448    LaDainian Tomlinson  NYJ      MIN     away  15.0    0    0    0   0
# 453          Peyton Hillis  CLE      ATL     away  15.0    0    0    0   0
# 454             Frank Gore   SF      PHI     away  15.0    0    0    0   0
# 464         Steven Jackson  STL      DET     home  13.0    0    0    0   0
# 500          Jeremy Maclin  PHI      ATL     away  34.0    0    0    0   0
# 504           Arian Foster  HOU       KC     away  27.0    0    0    0   0
# 505              Tony Romo  DAL      MIN     home  26.0   32   24  220   3
# 508             Drew Brees   NO       TB     home  26.0   32   21  263   3
# 509         Calvin Johnson  DET      NYG     home  25.0    0    0    0   0
# 514          Aaron Rodgers   GB      MIA     away  23.0   33   18  313   1
# 515         Peyton Manning  IND      WAS     home  23.0   38   25  307   2
# 517          Mike Williams  SEA      CHI     home  22.0    0    0    0   0
# 518       Brandon Marshall  MIA       GB     home  22.0    0    0    0   0
# 520        Benjamin Watson  CLE      PIT     home  20.0    0    0    0   0
# 521    LaDainian Tomlinson  NYJ      DEN     home  20.0    0    0    0   0
# 524             Alex Smith   SF      OAK     away  19.0   33   16  196   2
# 525              Matt Ryan  ATL      PHI     home  19.0   42   23  250   2
# 527            Eli Manning  NYG      DET     away  19.0   30   20  177   2
# 534          Austin Collie  IND      WAS     home  18.0    0    0    0   0
# 538         Steven Jackson  STL       SD     away  17.0    0    0    0   0
# 542           Joseph Addai  IND      WAS     home  17.0    0    0    0   0
# 546             Kyle Orton  DEN      NYJ     away  16.0   34   14  209   1
# 549         Ahmad Bradshaw  NYG      DET     away  16.0    0    0    0   0
# ...                    ...  ...      ...      ...   ...  ...  ...  ...  ..
# 12762      Deonte Thompson  BUF       NE     home  13.0    0    0    0   0
# 12764          Eric Decker  TEN       LA     away  13.0    0    0    0   0
# 12765          Andy Dalton  CIN      DET     away  13.0   41   27  238   1
# 12766           Drew Brees   NO      ATL     away  13.0   28   21  239   1
# 12767         Doug Baldwin  SEA      DAL     home  13.0    0    0    0   0
# 12768        Sammy Watkins   LA      TEN     home  12.0    0    0    0   0
# 12769         Tyrod Taylor  BUF       NE     home  12.0   38   21  281   0
# 12771     Matthew Stafford  DET      CIN     home  12.0   35   19  203   1
# 12772        Kyle Juszczyk   SF      JAX     away  12.0    0    0    0   0
# 12773           Ryan Grant  WAS      DEN     away  12.0    0    0    0   0
# 12781    0     ...          RB            0            1            0
# 12782    0     ...          WR            0            0            0
# 12783    0     ...          WR            0            0            0
# 12784    0     ...          WR            0            0            0
# 12785    0     ...          WR            0            0            0
# 12787    0     ...          RB            0            1            0
# 12789    0     ...          RB            0            1            0
# 12790    1     ...          QB            1            0            0
# 12793    0     ...          WR            0            0            0
# 12794    0     ...          RB            0            1            0
# 12795    0     ...          RB            0            1            0
# 12796    0     ...          WR            0            0            0
# 12797    0     ...          TE            0            0            1
# 12798    0     ...          WR            0            0            0
# 12799    0     ...          WR            0            0            0
#
#        Position_WR  opp_team  team  player_id               player  5_game_avg
# 400              1         2    20          7         Hakeem Nicks        21.6
# 407              0         4    25         16        Philip Rivers        25.4
# 415              0        31     9         41           Kyle Orton        22.4
# 422              1        16    14         14          Roddy White        19.8
# 429              0         4    25         31        Antonio Gates        23.2
# 435              0         5    11         46        Aaron Rodgers        22.0
# 443              0        15    23         49           Drew Brees        20.0
# 448              0        22    21         96  LaDainian Tomlinson        16.8
# 453              0        14    16         47        Peyton Hillis        18.4
# 454              0        19    13         63           Frank Gore        21.2
# 464              0         1    17         73       Steven Jackson        13.6
# 500              1        14    19         53        Jeremy Maclin        19.6
# 504              0        12     2          0         Arian Foster        26.4
# 505              0        22    29         37            Tony Romo        22.0
# 508              0        27    23         49           Drew Brees        22.2
# 509              1        20     1        116       Calvin Johnson        18.8
# 514              0        30    11         46        Aaron Rodgers        23.6
# 515              0         5     0          2       Peyton Manning        28.2
# 517              1        18    28         51        Mike Williams        16.0
# 518              1        11    30         60     Brandon Marshall        17.6
# 520              0        10    16        144      Benjamin Watson        13.2
# 521              0         9    21         96  LaDainian Tomlinson        19.0
# 524              0         4    13        113           Alex Smith        16.8
# 525              0        19    14        103            Matt Ryan        18.6
# 527              0         1    20         20          Eli Manning        18.2
# 534              1         5     0          4        Austin Collie        23.4
# 538              0        25    17         73       Steven Jackson        14.6
# 542              0         5     0         78         Joseph Addai        15.4
# 546              0        21     9         41           Kyle Orton        22.4
# 549              0         1    20         50       Ahmad Bradshaw        16.6
# ...            ...       ...   ...        ...                  ...         ...
# 12762            1         3    26        773      Deonte Thompson        15.0
# 12764            1        32     8        318          Eric Decker        14.8
# 12765            0         1     7        319          Andy Dalton        20.2
# 12766            0        14    23         49           Drew Brees        17.0
# 12767            1        29    28        310         Doug Baldwin        13.6
# 12768            1         8    32        563        Sammy Watkins        13.0
# 12769            0         3    26        640         Tyrod Taylor        20.4
# 12771            0         7     1        238     Matthew Stafford        16.6
# 12772            0        24    13        575        Kyle Juszczyk        11.4
# 12773            1         9     5        384           Ryan Grant        13.6
# 12775            0         9     5         48         Vernon Davis        13.0
# 12776            1         3    26        556      Kelvin Benjamin        13.8
# 12778            1        12    30        698       DeVante Parker        12.2
# 12779            0        32     8        636       Marcus Mariota        17.4
# 12780            0        11    22        516          Case Keenum        22.0
# 12781            0        15    20        814        Wayne Gallman        12.8
# 12782            1        21    33        497         Keenan Allen        25.4
# 12783            1        21    33        719      Tyrell Williams        15.6
# 12784            1         0    31        150         Mike Wallace        13.2
# 12785            1        14    23        724       Michael Thomas        17.8
# 12787            0        19     4        220       Marshawn Lynch        14.6
# 12789            0        26     3        702       Mike Gillislee        14.2
# 12790            0         4    19        455           Nick Foles        18.2
# 12793            1        20    15        572           John Brown        13.6
# 12794            0         5     9        748      Devontae Booker        11.8
# 12795            0        10     2        618          Alfred Blue        14.0
# 12796            1        33    21        750       Robby Anderson        18.4
# 12797            0         0    31        144      Benjamin Watson        11.2
# 12798            1         5     9        107     Demaryius Thomas        15.0
# 12799            1        15    20        715     Sterling Shepard        17.2
#
# [9984 rows x 33 columns]

# %%
new_df[new_df.loc[:, 'Player'] == 'Arian Foster'].head()
# Out:
#            Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0    Arian Foster  HOU      IND     away  42.0    0    0    0   0    0
# 157  Arian Foster  HOU      WAS     home  15.0    0    0    0   0    0
# 261  Arian Foster  HOU      DAL     away  15.0    0    0    0   0    0
# 303  Arian Foster  HOU      OAK     home  33.0    0    0    0   0    0
# 504  Arian Foster  HOU       KC     away  27.0    0    0    0   0    0
#
#         ...      pos_id  Position_QB  Position_RB  Position_TE  Position_WR  \
# 0       ...          RB            0            1            0            0
# 157     ...          RB            0            1            0            0
# 261     ...          RB            0            1            0            0
# 303     ...          RB            0            1            0            0
# 504     ...          RB            0            1            0            0
#
#      opp_team  team  player_id        player  5_game_avg
# 0           0     2          0  Arian Foster         NaN
# 157         5     2          0  Arian Foster         NaN
# 261        29     2          0  Arian Foster         NaN
# 303         4     2          0  Arian Foster         NaN
# 504        12     2          0  Arian Foster        26.4
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Label encode is_home

# %%
new_df['is_home'] = new_df['Location'].astype('category').cat.codes
new_df.head()
# Out:
#            Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  Int  \
# 0    Arian Foster  HOU      IND     away  42.0    0    0    0   0    0
# 1      Matt Forte  CHI      DET     away  38.0    0    0    0   0    0
# 2  Peyton Manning  IND      HOU     home  35.0   57   40  433   3    0
# 3    Chad Johnson  CIN       NE     home  33.0    0    0    0   0    0
# 4   Austin Collie  IND      HOU     home  32.0    0    0    0   0    0
#
#     ...     Position_QB  Position_RB  Position_TE  Position_WR  opp_team  \
# 0   ...               0            1            0            0         0
# 1   ...               0            1            0            0         1
# 2   ...               1            0            0            0         2
# 3   ...               0            0            0            1         3
# 4   ...               0            0            0            1         2
#
#    team  player_id          player  5_game_avg  is_home
# 0     2          0    Arian Foster         NaN        0
# 1    18          1      Matt Forte         NaN        0
# 2     0          2  Peyton Manning         NaN        1
# 3     7          3    Chad Johnson         NaN        1
# 4     0          4   Austin Collie         NaN        1
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Compute diff from running average

# %%
new_df['diff_from_avg'] = new_df['Pts'] - new_df['5_game_avg']
new_df.dropna()
# Out:
#                     Player Team Opponent Location   Pts  Att  Cmp  Yds  TD  \
# 400           Hakeem Nicks  NYG      HOU     home  37.0    0    0    0   0
# 407          Philip Rivers   SD      OAK     home  28.0   42   27  431   2
# 415             Kyle Orton  DEN      BAL     home  24.0   38   23  314   2
# 422            Roddy White  ATL      CLE     home  21.0    0    0    0   0
# 429          Antonio Gates   SD      OAK     home  20.0    0    0    0   0
# 538              2.4
# 542              1.6
# 546             -6.4
# 549             -0.6
# ...              ...
# 12762           -2.0
# 12764           -1.8
# 12765           -7.2
# 12766           -4.0
# 12767           -0.6
# 12768           -1.0
# 12769           -8.4
# 12771           -4.6
# 12772            0.6
# 12773           -1.6
# 12775           -1.0
# 12776           -1.8
# 12778           -1.2
# 12779           -6.4
# 12780          -11.0
# 12781           -1.8
# 12782          -14.4
# 12783           -5.6
# 12784           -3.2
# 12785           -7.8
# 12787           -4.6
# 12789           -4.2
# 12790           -8.2
# 12793           -3.6
# 12794           -1.8
# 12795           -4.0
# 12796           -8.4
# 12797           -2.2
# 12798           -6.0
# 12799           -8.2
#
# [9984 rows x 35 columns]

# %% [markdown]
# ### Assign player rank based on rolling average

# %%
new_df['week_year'] = new_df['Week'].astype(str) + '_' + new_df['Year'].astype(str)

# %%
new_df['rank'] = new_df.groupby(['Week'])['5_game_avg'].apply(lambda x: pd.qcut(x, 5, labels=['4','3','2','1','0']))
new_df[new_df.loc[:, 'week_year'] == '5_2017'].sort_values(by='5_game_avg')
# Out:
#                         Player Team Opponent Location   Pts  Att  Cmp  Yds  \
# 11682             Marvin Jones  DET      CAR     away  11.0    0    0    0
# 11676           Marshawn Lynch  OAK      BAL     away  12.0    0    0    0
# 11690            Jeremy Maclin  BAL      OAK     home  10.0    0    0    0
# 11679         Benny Cunningham  CHI      MIN     away  12.0    0    0    0
# 11672              James White   NE       TB     home  12.0    0    0    0
# 11659              Doug Martin   TB       NE     away  14.0    0    0    0
# 11640             Mike Wallace  BAL      OAK     home  16.0    0    0    0
# 11692               Frank Gore  IND       SF     away  10.0    0    0    0
# 11675              Zach Miller  CHI      MIN     away  12.0    0    0    0
# 11650             Jimmy Graham  SEA       LA     home  15.0    0    0    0
# 11642             Kyle Rudolph  MIN      CHI     home  16.0    0    0    0
# 11686             Brandon Tate  BUF      CIN     home  10.0    0    0    0
# 11664          Jermaine Kearse  NYJ      CLE     home  13.0    0    0    0
# 11654          Kelvin Benjamin  CAR      DET     home  15.0    0    0    0
# 11695             Keenan Allen  LAC      NYG     home  10.0    0    0    0
# 11651          Andre Ellington  ARI      PHI     home  15.0    0    0    0
# 11685             Tyrod Taylor  BUF      CIN     home  10.0   37   20  166
# 11689             Lamar Miller  HOU       KC     away  10.0    0    0    0
# 11667             Hunter Henry  LAC      NYG     home  13.0    0    0    0
# 11684             Tavon Austin   LA      SEA     away  11.0    0    0    0
# 11648            Jarvis Landry  MIA      TEN     away  15.0    0    0    0
# 11634              Josh McCown  NYJ      CLE     home  17.0   30   23  194
# 11697              Golden Tate  DET      CAR     away   9.0    0    0    0
# 11637            Pierre Garcon   SF      IND     home  17.0    0    0    0
# 11641             Torrey Smith  PHI      ARI     away  16.0    0    0    0
# 11629                Zach Ertz  PHI      ARI     away  18.0    0    0    0
# 11694               John Brown  ARI      PHI     home  10.0    0    0    0
# 11626           Nelson Agholor  PHI      ARI     away  19.0    0    0    0
# 11628           Devin Funchess  CAR      DET     home  18.0    0    0    0
# 11660             Jason Witten  DAL       GB     away  13.0    0    0    0
# ...                        ...  ...      ...      ...   ...  ...  ...  ...
# 11610            Philip Rivers  LAC      NYG     home  26.0   44   21  258
# 11613            Antonio Brown  PIT      JAX     away  25.0    0    0    0
# 11615                TY Hilton  IND       SF     away  24.0    0    0    0
# 11663              Case Keenum  MIN      CHI     home  13.0   21   17  140
# 11601             Carson Wentz  PHI      ARI     away  35.0   30   21  304
# 11612              Brian Hoyer   SF      IND     home  26.0   46   29  353
# 11665              Kareem Hunt   KC      HOU     home  13.0    0    0    0
# 11602             Dak Prescott  DAL       GB     away  35.0   36   25  251
# 11608            Aaron Rodgers   GB      DAL     home  29.0   29   19  221
# 11653                Tom Brady   NE       TB     home  15.0   40   30  303
# 11605               Alex Smith   KC      HOU     home  31.0   37   29  324
# 11600           Deshaun Watson  HOU       KC     away  45.0   31   16  261
# 11617            George Kittle   SF      IND     home  21.0    0    0    0
# 11621              Kevin Hogan  CLE      NYJ     away  20.0   19   16  194
# 11624              Aaron Jones   GB      DAL     home  19.0    0    0    0
# 11638          Jacoby Brissett  IND       SF     away  17.0   34   22  314
# 11643              Marlon Mack  IND       SF     away  16.0    0    0    0
# 11645             Darren Fells  DET      CAR     away  16.0    0    0    0
# 11656  Austin Seferian-Jenkins  NYJ      CLE     home  14.0    0    0    0
# 11658      Christian McCaffrey  CAR      DET     home  14.0    0    0    0
# 11661              David Njoku  CLE      NYJ     away  13.0    0    0    0
# 11666             Tyler Higbee   LA      SEA     away  13.0    0    0    0
# 11669           Orleans Darkwa  NYG      LAC     away  13.0    0    0    0
# 11673        Mitchell Trubisky  CHI      MIN     away  12.0   25   12  128
# 11677            Ricardo Louis  CLE      NYJ     away  12.0    0    0    0
# 11678            Wayne Gallman  NYG      LAC     away  12.0    0    0    0
# 11681                Joe Mixon  CIN      BUF     away  11.0    0    0    0
# 11687             Nick O'Leary  BUF      CIN     home  10.0    0    0    0
# 11698         Phillip Supernaw  TEN      MIA     home   9.0    0    0    0
# 11699      JuJu Smith-Schuster  PIT      JAX     away   9.0    0    0    0
#
#        TD  Int  ...   Position_WR  opp_team  team  player_id  \
# 11682   0    0  ...             1         6     1        471
# 11676   0    0  ...             0        31     4        220
# 11690   0    0  ...             1         4    31         53
# 11679   0    0  ...             0        22    18        533
# 11672   0    0  ...             0        27     3        693
# 11659   0    0  ...             0         3    27        402
# 11640   0    0  ...             1         4    31        150
# 11692   0    0  ...             0        13     0         63
# 11675   0    0  ...             0        22    18        160
# 11650   0    0  ...             0        32    28        259
# 11642   0    0  ...             0        18    22        375
# 11686   0    0  ...             1         7    26        240
# 11664   0    0  ...             1        16    21        480
# 11654   0    0  ...             1         1     6        556
# 11695   0    0  ...             1        20    33        497
# 11651   0    0  ...             0        19    15        485
# 11685   1    1  ...             0         7    26        640
# 11689   0    0  ...             0        12     2        416
# 11667   0    0  ...             0        20    33        730
# 11684   0    0  ...             1        28    32        482
# 11648   0    0  ...             1         8    30        592
# 11634   2    1  ...             0        16    21        393
# 11697   0    0  ...             1         6     1        380
# 11637   0    0  ...             1         0    13        208
# 11641   0    0  ...             1        15    19        327
# 11629   0    0  ...             0        15    19        525
# 11694   0    0  ...             1        19    15        572
# 11626   0    0  ...             1        15    19        700
# 11628   0    0  ...             1         1     6        685
# 11660   0    0  ...             0        11    29        142
# ...    ..  ...  ...           ...       ...   ...        ...
# 11610   3    1  ...             0        20    33         16
# 11613   0    0  ...             1        24    10        333
# 11615   0    0  ...             1        13     0        419
# 11663   1    0  ...             0        18    22        516
# 11601   4    1  ...             0        15    19        706
# 11612   2    0  ...             0         0    13        488
# 11665   0    0  ...             0         2    12        784
# 11602   3    1  ...             0        11    29        718
# 11608   3    0  ...             0        29    11         46
# 11653   1    1  ...             0        27     3          8
# 11605   3    0  ...             0         2    12        113
# 11600   5    0  ...             0        12     2        794
# 11617   0    0  ...             0         0    13        816
# 11621   2    1  ...             0        21    16        747
# 11624   0    0  ...             0        29    11        815
# 11638   0    1  ...             0        13     0        725
# 11643   0    0  ...             0        13     0        793
# 11645   0    0  ...             0         6     1        638
# 11656   0    0  ...             0        16    21        613
# 11658   0    0  ...             0         1     6        792
# 11661   0    0  ...             0        21    16        800
# 11666   0    0  ...             0        28    32        817
# 11669   0    0  ...             0        33    20        729
# 11673   1    1  ...             0        22    18        818
# 11677   0    0  ...             1        21    16        741
# 11678   0    0  ...             0        33    20        814
# 11681   0    0  ...             0        26     7        804
# 11687   0    0  ...             0         7    26        819
# 11698   0    0  ...             0        30     8        820
# 11699   0    0  ...             1        24    10        801
#
#                         player  5_game_avg  is_home  diff_from_avg  week_year  \
# 11682             Marvin Jones        11.6        0           -0.6     5_2017
# 11676           Marshawn Lynch        12.4        0           -0.4     5_2017
# 11690            Jeremy Maclin        12.6        1           -2.6     5_2017
# 11679         Benny Cunningham        12.6        0           -0.6     5_2017
# 11672              James White        13.0        1           -1.0     5_2017
# 11659              Doug Martin        13.2        0            0.8     5_2017
# 11640             Mike Wallace        13.2        1            2.8     5_2017
# 11692               Frank Gore        13.6        0           -3.6     5_2017
# 11675              Zach Miller        13.6        0           -1.6     5_2017
# 11650             Jimmy Graham        13.8        1            1.2     5_2017
# 11642             Kyle Rudolph        14.0        1            2.0     5_2017
# 11686             Brandon Tate        14.0        1           -4.0     5_2017
# 11664          Jermaine Kearse        14.2        1           -1.2     5_2017
# 11654          Kelvin Benjamin        14.2        1            0.8     5_2017
# 11695             Keenan Allen        14.6        1           -4.6     5_2017
# 11651          Andre Ellington        14.8        1            0.2     5_2017
# 11685             Tyrod Taylor        15.2        1           -5.2     5_2017
# 11689             Lamar Miller        15.2        0           -5.2     5_2017
# 11667             Hunter Henry        15.2        1           -2.2     5_2017
# 11684             Tavon Austin        15.4        0           -4.4     5_2017
# 11648            Jarvis Landry        15.4        0           -0.4     5_2017
# 11634              Josh McCown        15.6        1            1.4     5_2017
# 11697              Golden Tate        15.6        0           -6.6     5_2017
# 11637            Pierre Garcon        15.8        1            1.2     5_2017
# 11641             Torrey Smith        15.8        0            0.2     5_2017
# 11629                Zach Ertz        16.0        0            2.0     5_2017
# 11694               John Brown        16.0        1           -6.0     5_2017
# 11626           Nelson Agholor        16.2        0            2.8     5_2017
# 11628           Devin Funchess        16.2        1            1.8     5_2017
# 11660             Jason Witten        16.2        0           -3.2     5_2017
# ...                        ...         ...      ...            ...        ...
# 11610            Philip Rivers        22.8        1            3.2     5_2017
# 11613            Antonio Brown        23.4        0            1.6     5_2017
# 11615                TY Hilton        23.4        0            0.6     5_2017
# 11663              Case Keenum        23.4        1          -10.4     5_2017
# 11601             Carson Wentz        23.4        0           11.6     5_2017
# 11612              Brian Hoyer        23.6        1            2.4     5_2017
# 11665              Kareem Hunt        24.8        1          -11.8     5_2017
# 11602             Dak Prescott        25.2        0            9.8     5_2017
# 11608            Aaron Rodgers        26.0        1            3.0     5_2017
# 11653                Tom Brady        26.0        1          -11.0     5_2017
# 11605               Alex Smith        26.6        1            4.4     5_2017
# 11600           Deshaun Watson         NaN        0            NaN     5_2017
# 11617            George Kittle         NaN        1            NaN     5_2017
# 11621              Kevin Hogan         NaN        0            NaN     5_2017
# 11624              Aaron Jones         NaN        1            NaN     5_2017
# 11638          Jacoby Brissett         NaN        0            NaN     5_2017
# 11643              Marlon Mack         NaN        0            NaN     5_2017
# 11645             Darren Fells         NaN        0            NaN     5_2017
# 11656  Austin Seferian-Jenkins         NaN        1            NaN     5_2017
# 11658      Christian McCaffrey         NaN        1            NaN     5_2017
# 11661              David Njoku         NaN        0            NaN     5_2017
# 11666             Tyler Higbee         NaN        0            NaN     5_2017
# 11669           Orleans Darkwa         NaN        0            NaN     5_2017
# 11673        Mitchell Trubisky         NaN        0            NaN     5_2017
# 11677            Ricardo Louis         NaN        0            NaN     5_2017
# 11678            Wayne Gallman         NaN        0            NaN     5_2017
# 11681                Joe Mixon         NaN        0            NaN     5_2017
# 11687             Nick O'Leary         NaN        1            NaN     5_2017
# 11698         Phillip Supernaw         NaN        1            NaN     5_2017
# 11699      JuJu Smith-Schuster         NaN        0            NaN     5_2017
#
#        rank
# 11682     4
# 11676     4
# 11690     4
# 11679     4
# 11672     4
# 11659     4
# 11640     4
# 11692     4
# 11675     4
# 11650     4
# 11642     4
# 11686     4
# 11664     4
# 11654     4
# 11695     4
# 11651     4
# 11685     3
# 11689     3
# 11667     3
# 11684     3
# 11648     3
# 11634     3
# 11697     3
# 11637     3
# 11641     3
# 11629     3
# 11694     3
# 11626     3
# 11628     3
# 11660     3
# ...     ...
# 11610     0
# 11613     0
# 11615     0
# 11663     0
# 11601     0
# 11612     0
# 11665     0
# 11602     0
# 11608     0
# 11653     0
# 11605     0
# 11600   NaN
# 11617   NaN
# 11621   NaN
# 11624   NaN
# 11638   NaN
# 11643   NaN
# 11645   NaN
# 11656   NaN
# 11658   NaN
# 11661   NaN
# 11666   NaN
# 11669   NaN
# 11673   NaN
# 11677   NaN
# 11678   NaN
# 11681   NaN
# 11687   NaN
# 11698   NaN
# 11699   NaN
#
# [100 rows x 37 columns]

# %% [markdown]
# ## Before proceeding, let's drop the useless columns and save our updated table

# %%
new_df.columns
# Out:
# Index(['Player', 'Team', 'Opponent', 'Location', 'Pts', 'Att', 'Cmp', 'Yds',
#        'TD', 'Int', '2Pt', 'Rush Att', 'Rush Yds', 'Rush TD', 'Rush 2Pt',
#        'Rec', 'Rec Yds', 'Rec TD', 'Rec 2Pt', 'FL', 'Misc TD', 'Week', 'Year',
#        'pos_id', 'Position_QB', 'Position_RB', 'Position_TE', 'Position_WR',
#        'opp_team', 'team', 'player_id', 'player', '5_game_avg', 'is_home',
#        'diff_from_avg', 'week_year', 'rank'],
#       dtype='object')

# %%
final_df = new_df.loc[:, ['Player', 'pos_id', 'Team', 'Opponent', 'Pts', 'Week', 'Year', 
                          'Position_QB', 'Position_RB', 'Position_TE', 'Position_WR',
                          'opp_team', 'team', 'player_id', '5_game_avg', 'is_home',
                          'diff_from_avg', 'week_year', 'rank']]
final_df.shape
final_df.to_csv("./data/updated_table.csv", index=None)

# %%
# Drop na to not mess with the training
clean_df = final_df.dropna()
clean_df.shape
# Out:
# (9984, 19)

# %% [markdown]
# ### Split data for training and testing

# %%
train = clean_df[clean_df.apply(lambda x: x['Year'] == 2015, axis=1)]
test = clean_df[clean_df.apply(lambda x: x['Year'] == 2016, axis=1)]
cv = clean_df[clean_df.apply(lambda x: x['Year'] == 2017, axis=1)]

# %% [markdown]
# ## Implement the model

# %%
import theano
import pymc3 as pm
theano.__version__
# Out:
# '1.0.2'

# %%
train.head()
# Out:
#                Player pos_id Team Opponent   Pts  Week  Year  Position_QB  \
# 8000      Julio Jones     WR  ATL      PHI  35.0     1  2015            0
# 8001        Tom Brady     QB   NE      PIT  35.0     1  2015            1
# 8003  DeAndre Hopkins     WR  HOU       KC  32.0     1  2015            0
# 8004   Rob Gronkowski     TE   NE      PIT  32.0     1  2015            0
# 8005    Carson Palmer     QB  ARI       NO  31.0     1  2015            1
#
#       Position_RB  Position_TE  Position_WR  opp_team  team  player_id  \
# 8000            0            0            1        19    14        314
# 8001            0            0            0        10     3          8
# 8003            0            0            1        12     2        481
# 8004            0            1            0        10     3        167
# 8005            0            0            0        23    15         17
#
#       5_game_avg  is_home  diff_from_avg week_year rank
# 8000        29.0        0            6.0    1_2015    0
# 8001        24.6        0           10.4    1_2015    0
# 8003        24.6        0            7.4    1_2015    0
# 8004        20.6        0           11.4    1_2015    1
# 8005        24.6        0            6.4    1_2015    0

# %%
num_positions=4
ranks=5
team_number = len(team_names)
np.random.seed(42)

with pm.Model() as model:
    nu = pm.Exponential('nu minus one', 1/29.,shape=2) + 1 # from https://pymc-devs.github.io/pymc3/notebooks/BEST.html
    err = pm.Uniform('std dev based on rank', 0, 100, shape=ranks)
    err_b = pm.Uniform('std dev based on rank b', 0, 100, shape=ranks)

    # Theano shared variables to change at test time
    player_home = theano.shared(np.asarray(train['is_home'].values, dtype = int))
    player_avg = theano.shared(np.asarray((train['5_game_avg']).values, dtype = float))
    player_opp = theano.shared(np.asarray((train['opp_team']).values, dtype = int))
    player_team = theano.shared(np.asarray((train['team']).values, dtype = int))
    player_rank = theano.shared(np.asarray((train['rank']).values, dtype = int))
    qb = theano.shared(np.asarray((train['Position_QB']).values.astype(int), dtype = int))
    wr = theano.shared(np.asarray((train['Position_WR']).values.astype(int), dtype = int))
    rb = theano.shared(np.asarray((train['Position_RB']).values.astype(int), dtype = int))
    te = theano.shared(np.asarray((train['Position_TE']).values.astype(int), dtype = int))
    pos_id = theano.shared(np.asarray((train['pos_id']).values, dtype = str))

# %%
with model:
    # Defensive ability of the opposing team vs. each position, partially pooled
    opp_def = pm.Normal('opp team prior',0, sd=100**2, shape=num_positions)
    opp_qb = pm.Normal('defensive differential qb', opp_def[0], sd=100**2, shape=team_number)
    opp_wr = pm.Normal('defensive differential wr', opp_def[1], sd=100**2, shape=team_number)
    opp_rb = pm.Normal('defensive differential rb', opp_def[2], sd=100**2, shape=team_number)
    opp_te = pm.Normal('defensive differential te', opp_def[3], sd=100**2, shape=team_number)
    
    # Partially pooled ability of the player's rank partially pooled based on position
    home_adv = pm.Normal('home additivie prior', 0, 100**2,shape = num_positions)     
    away_adv = pm.Normal('away additivie prior', 0, 100**2,shape = num_positions)     
    pos_home_qb = pm.Normal('home differential qb',home_adv[0],10**2, shape = ranks)
    pos_home_rb = pm.Normal('home differential rb',home_adv[1],10**2, shape = ranks)
    pos_home_te = pm.Normal('home differential te',home_adv[2],10**2, shape = ranks)
    pos_home_wr = pm.Normal('home differential wr',home_adv[3],10**2, shape = ranks)
    pos_away_qb = pm.Normal('away differential qb',away_adv[0],10**2, shape = ranks)
    pos_away_rb = pm.Normal('away differential rb',away_adv[1],10**2, shape = ranks)
    pos_away_wr = pm.Normal('away differential wr',away_adv[2],10**2, shape = ranks)
    pos_away_te = pm.Normal('away differential te',away_adv[3],10**2, shape = ranks)

# %%
with model:
    # First likelihood where the player's difference from average is explained by defensive abililty
    def_effect = qb*opp_qb[player_opp]+ wr*opp_wr[player_opp]+ rb*opp_rb[player_opp]+ te*opp_te[player_opp]
    like1 = pm.StudentT('Diff From Avg', mu=def_effect, sd=err_b[player_rank],nu=nu[1], observed = train['diff_from_avg'])
    
    # Second likelihood where the score is predicted by defensive power plus other smaller factors
    mu = player_avg + def_effect
    mu += rb*pos_home_rb[player_rank]*(player_home) + wr*pos_home_wr[player_rank]*(player_home) 
    mu += qb*pos_home_qb[player_rank]*(player_home) + te*pos_home_te[player_rank]*(player_home) 
    mu += rb*pos_away_rb[player_rank]*(1-player_home) + wr*pos_away_wr[player_rank]*(1-player_home) 
    mu += qb*pos_away_qb[player_rank]*(1-player_home) + te*pos_away_te[player_rank]*(1-player_home) 
    like2 = pm.StudentT('Score', mu=mu, sd=err[player_rank], nu=nu[0], observed=train['Pts'])

    # Training!
    trace=pm.sample(10000, pm.Metropolis())
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [away differential te]
# >Metropolis: [away differential wr]
# >Metropolis: [away differential rb]
# >Metropolis: [away differential qb]
# >Metropolis: [home differential wr]
# >Metropolis: [home differential te]
# >Metropolis: [home differential rb]
# >Metropolis: [home differential qb]
# >Metropolis: [away additivie prior]
# >Metropolis: [home additivie prior]
# >Metropolis: [defensive differential te]
# >Metropolis: [defensive differential rb]
# >Metropolis: [defensive differential wr]
# >Metropolis: [defensive differential qb]
# >Metropolis: [opp team prior]
# >Metropolis: [std dev based on rank b]
# >Metropolis: [std dev based on rank]
# >Metropolis: [nu minus one]
# Sampling 4 chains:   0%|                                                                                                                                                                          | 8/42000 [00:55<72:51:34,  6.25s/draws]
